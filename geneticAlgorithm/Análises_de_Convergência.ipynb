# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
scores = pd.read_csv("https://raw.githubusercontent.com/rafaelgdp/smart-pacman/master/geneticAlgorithm/scores_64gen.txt")
scores
# Out:
#      generation  id  ...  winRate                                             scores
# 0             0   0  ...      0.0  [-580.0, -558.0, -530.0, -769.0, -553.0, -534....
# 1             0   1  ...      0.0  [-293.0, -183.0, -275.0, -38.0, 324.0, -185.0,...
# 2             0   2  ...      0.0  [-579.0, -767.0, -544.0, -522.0, -565.0, -595....
# 3             0   3  ...      0.3  [-139.0, 399.0, 2459.0, 2044.0, 200.0, 2284.0,...
# 4             0   4  ...      0.0  [-432.0, -686.0, -837.0, -599.0, -668.0, -616....
# ..          ...  ..  ...      ...                                                ...
# 957          63  12  ...      0.2  [-89.0, 2144.0, -124.0, 2495.0, 1131.0, -186.0...
# 958          63  13  ...      0.0  [511.0, 554.0, 1270.0, 927.0, 213.0, 867.0, 29...
# 959          63  14  ...      0.1  [626.0, 789.0, 1091.0, 1206.0, 380.0, 591.0, 1...
# 960          64   0  ...      0.2  [2023.0, 738.0, 1603.0, -221.0, 427.0, 882.0, ...
# 961          64   1  ...      0.1  [1340.0, 679.0, 395.0, 1461.0, 673.0, -169.0, ...
#
# [962 rows x 8 columns]

# %%
g = ['G'+str(n) for n in range(0,64,1)]

fig, ax = plt.subplots(figsize=(16, 8))
ax = sns.boxplot(x='generation', y='averageScore', data=scores)
ax.set_xticks(np.arange(64) )
ax.set_xticklabels(g)
ax.set_ylabel('Pontuação', fontsize=15)
ax.set_xlabel('Geração', fontsize=15)
ax.set_title('Análise da Convergência do Score Médio')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16, 8))
ax = sns.boxplot(x='generation', y='winRate', data=scores)
ax.set_xticks(np.arange(64) )
ax.set_xticklabels(g)
ax.set_ylabel('Winning Rate', fontsize=15)
ax.set_xlabel('Geração', fontsize=15)
ax.set_title('Análise da Convergência da Taxa de Vitória')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16, 8))
ax = sns.boxplot(x='generation', y='w1', data=scores)
ax.set_xticks(np.arange(64) )
ax.set_xticklabels(g)
ax.set_ylabel('W1', fontsize=15)
ax.set_xlabel('Geração', fontsize=15)
ax.set_title('Análise da Convergência do W1')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16, 8))
ax = sns.boxplot(x='generation', y='w2', data=scores)
ax.set_xticks(np.arange(64))
ax.set_xticklabels(g)
ax.set_ylabel('W2', fontsize=15)
ax.set_xlabel('Geração', fontsize=15)
ax.set_title('Análise da Convergência do W2')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16, 8))
ax = sns.boxplot(x='generation', y='w3', data=scores)
ax.set_xticks(np.arange(64) )
ax.set_xticklabels(g)
ax.set_ylabel('W3', fontsize=15)
ax.set_xlabel('Geração', fontsize=15)
ax.set_title('Análise da Convergência do W3')
plt.show()
